# %%
import pandas as pd

data=pd.read_csv('large_cap.csv')
data
# Out:
#             Date        AAPL        ABBV         ABT         ACN        ADBE  \
# 0     2012-02-21   15.744738         NaN   22.065088   47.881710   32.540001
# 1     2012-02-22   15.689387         NaN   22.092596   48.202892   32.330002
# 2     2012-02-23   15.791832         NaN   22.116167   48.927624   32.970001
# 3     2012-02-24   15.975932         NaN   22.277252   49.125282   33.410000
# 4     2012-02-27   16.078384         NaN   22.237967   49.133511   33.270000
# ...          ...         ...         ...         ...         ...         ...
# 2513  2022-02-14  168.880005  143.000000  122.779999  326.130005  474.010010
# 2514  2022-02-15  172.789993  144.759995  123.980003  329.410004  479.500000
# 2515  2022-02-16  172.550003  145.869995  123.680000  333.720001  477.700012
# 2516  2022-02-17  168.880005  144.970001  120.580002  322.910004  457.709991
# 2517  2022-02-18  167.300003  144.029999  116.790001  321.179993  442.559998
#
# ...

# %%
l=[{'ticker':ticker,'n':len(data[ticker].dropna())} for ticker in data.columns]
lengths=pd.DataFrame(l)
lengths
# Out:
#    ticker     n
# 0    Date  2518
# 1    AAPL  2518
# 2    ABBV  2301
# 3     ABT  2518
# 4     ACN  2518
# ..    ...   ...
# 92      V  2518
# 93     VZ  2518
# 94    WFC  2518
# 95    WMT  2518
# 96    XOM  2518
#
# [97 rows x 2 columns]

# %%
lengths.n.mean()*.2*.2
# Out:
# 99.71711340206187
